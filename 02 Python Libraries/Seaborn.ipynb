# %% [markdown]
# <a href="https://colab.research.google.com/github/HeroHalder/AI-ML-Zero-to-Hero/blob/main/02%20Python%20Libraries/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hero Halder")
# Out:
# Hero Halder

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("planets")
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df2=sns.load_dataset("tips")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="day")
plt.savefig("Test.png")

# %%
plt.figure(figsize=(12,6),dpi=600)
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="day",palette="Set2")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",hue="day",palette="Paired")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",size="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",size=600)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",s=600)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",s=600,alpha=0.6)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=df2,x="total_bill",y="tip",style="sex",s=600,hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Rugplot

sns.rugplot(data=df2,x="total_bill",height=0.5)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(df2["total_bill"],height=0.6,color="red")
# Out:
# <Axes: xlabel='total_bill'>

# %%
#Displot

sns.displot(df2["total_bill"])

# %%
sns.displot(df2["total_bill"],kde=True,bins=60,color="green")

# %%
sns.displot(df2["total_bill"],kde=True,bins=60,color="red",rug=True)

# %%
sns.displot(df2["total_bill"],kde=True,bins=20,color="green",edgecolor="orange",lw=20,ls="--")

# %%
#Histplot=Displot nearly but hist=!Rug in same code
sns.histplot(df2["total_bill"],kde=True,bins=60,color="green")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#KDEPlot

sns.kdeplot(df2["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df2["total_bill"],bw_adjust=0.2)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df2["total_bill"],clip=[10,40])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df2["total_bill"],shade=True)
# Out:
# /tmp/ipykernel_792/3809253383.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df2["total_bill"],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(df2["total_bill"],fill=True)#shade==fill fill new version
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.ecdfplot(data=df2, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Proportion'>

# %%
sns.lineplot(data=df2, x="size", y="total_bill")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.regplot(data=df2, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=df2, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df2, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=df2, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(df2)

# %%
sns.FacetGrid(df2, col="time").map(sns.histplot, "total_bill")

# %%
corr = df2.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %%
sns.set_style("darkgrid")
sns.set_palette("deep")

sns.barplot(data=df2, x="day", y="total_bill")

plt.show()
