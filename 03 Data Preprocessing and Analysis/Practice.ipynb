# %%
print("Hero")
# Out:
# Hero

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load dataset

df= pd.read_csv(r"D:\Datasets\usa_housing_kaggle.csv")

# %%
df.head()  #See 1st 5 sample
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  LotSize  \
# 0  221958         1        1.9        4827       1979             2     1.45
# 1  771155         2        2.0        1035       1987             2     1.75
# 2  231932         1        3.0        2769       1982             1     1.46
# 3  465838         3        3.3        2708       1907             3     1.62
# 4  359178         4        3.4        1175       1994             2     0.74
#
#    ZipCode  CrimeRate  SchoolRating
# 0    82240      48.60             5
# 1    74315      92.03             9
# 2    79249      52.08             3
# 3    80587      61.65             1
# 4    20756      15.66             4

# %%
df.shape
# Out:
# (300, 10)

# %%
df.columns
# Out:
# Index(['Price', 'Bedrooms', 'Bathrooms', 'SquareFeet', 'YearBuilt',
#        'GarageSpaces', 'LotSize', 'ZipCode', 'CrimeRate', 'SchoolRating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         300 non-null    int64
#  1   Bedrooms      300 non-null    int64
#  2   Bathrooms     300 non-null    float64
#  3   SquareFeet    300 non-null    int64
#  4   YearBuilt     300 non-null    int64
#  5   GarageSpaces  300 non-null    int64
#  6   LotSize       300 non-null    float64
#  7   ZipCode       300 non-null    int64
#  8   CrimeRate     300 non-null    float64
#  9   SchoolRating  300 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#                Price    Bedrooms   Bathrooms  SquareFeet    YearBuilt  \
# count     300.000000  300.000000  300.000000   300.00000   300.000000
# mean   522761.916667    2.966667    2.464000  3052.75000  1962.616667
# std    256922.348275    1.451175    0.886184  1194.97144    36.005431
# min    112666.000000    1.000000    1.000000   840.00000  1902.000000
# 25%    299936.500000    2.000000    1.700000  2053.50000  1931.750000
# 50%    505806.500000    3.000000    2.400000  3127.00000  1961.000000
# 75%    744603.750000    4.000000    3.200000  4081.00000  1994.000000
# max    999684.000000    5.000000    4.000000  4997.00000  2022.000000
#
#        GarageSpaces     LotSize       ZipCode   CrimeRate  SchoolRating
# count    300.000000  300.000000    300.000000  300.000000    300.000000
# mean       1.513333    1.062200  54324.770000   49.324033      5.096667
# std        1.116832    0.543896  24718.938552   28.833220      2.674165
# ...

# %%
df.isnull().sum()
# Out:
# Price           0
# Bedrooms        0
# Bathrooms       0
# SquareFeet      0
# YearBuilt       0
# GarageSpaces    0
# LotSize         0
# ZipCode         0
# CrimeRate       0
# SchoolRating    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
sns.histplot(df["Price"],kde=True,bins=60)
plt.title("Prics Distribution")
plt.show()

# %%
sns.boxplot(x=df["Price"])
plt.title("Boxplot of Prize")
plt.show()

# %%
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  LotSize  \
# 0  221958         1        1.9        4827       1979             2     1.45
# 1  771155         2        2.0        1035       1987             2     1.75
# 2  231932         1        3.0        2769       1982             1     1.46
# 3  465838         3        3.3        2708       1907             3     1.62
# 4  359178         4        3.4        1175       1994             2     0.74
#
#    ZipCode  CrimeRate  SchoolRating
# 0    82240      48.60             5
# 1    74315      92.03             9
# 2    79249      52.08             3
# 3    80587      61.65             1
# 4    20756      15.66             4

# %%
sns.violinplot(x=df["Price"])
plt.title("Violine Plot")
plt.show()

# %%
df["Bathrooms"] = df["Bathrooms"].astype(int)

# %%
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  LotSize  \
# 0  221958         1          1        4827       1979             2     1.45
# 1  771155         2          2        1035       1987             2     1.75
# 2  231932         1          3        2769       1982             1     1.46
# 3  465838         3          3        2708       1907             3     1.62
# 4  359178         4          3        1175       1994             2     0.74
#
#    ZipCode  CrimeRate  SchoolRating
# 0    82240      48.60             5
# 1    74315      92.03             9
# 2    79249      52.08             3
# 3    80587      61.65             1
# 4    20756      15.66             4

# %%
sns.scatterplot(x=df["Bedrooms"], y=df["Price"])
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x=df["Bathrooms"], y=df["Price"])  #It has a Outlier
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Price'>

# %%
plt.plot(df["SquareFeet"], df["Price"])

plt.xlabel("SquareFeet")
plt.ylabel("Price")
plt.show()

# %%
df.drop("SquareFeet", axis=1,inplace=True)

# %%
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  YearBuilt  GarageSpaces  LotSize  ZipCode  \
# 0  221958         1          1       1979             2     1.45    82240
# 1  771155         2          2       1987             2     1.75    74315
# 2  231932         1          3       1982             1     1.46    79249
# 3  465838         3          3       1907             3     1.62    80587
# 4  359178         4          3       1994             2     0.74    20756
#
#    CrimeRate  SchoolRating
# 0      48.60             5
# 1      92.03             9
# 2      52.08             3
# 3      61.65             1
# 4      15.66             4

# %%
sns.scatterplot(x=df["YearBuilt"], y=df["Price"])
# Out:
# <Axes: xlabel='YearBuilt', ylabel='Price'>

# %%
df.drop("YearBuilt", axis=1,inplace=True)
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  GarageSpaces  LotSize  ZipCode  CrimeRate  \
# 0  221958         1          1             2     1.45    82240      48.60
# 1  771155         2          2             2     1.75    74315      92.03
# 2  231932         1          3             1     1.46    79249      52.08
# 3  465838         3          3             3     1.62    80587      61.65
# 4  359178         4          3             2     0.74    20756      15.66
#
#    SchoolRating
# 0             5
# 1             9
# 2             3
# 3             1
# 4             4

# %%
sns.scatterplot(x=df["GarageSpaces"], y=df["Price"])
# Out:
# <Axes: xlabel='GarageSpaces', ylabel='Price'>

# %%
sns.scatterplot(x=df["LotSize"], y=df["Price"])
# Out:
# <Axes: xlabel='LotSize', ylabel='Price'>

# %%
df.drop("LotSize", axis=1,inplace=True)

# %%
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  GarageSpaces  ZipCode  CrimeRate  SchoolRating
# 0  221958         1          1             2    82240      48.60             5
# 1  771155         2          2             2    74315      92.03             9
# 2  231932         1          3             1    79249      52.08             3
# 3  465838         3          3             3    80587      61.65             1
# 4  359178         4          3             2    20756      15.66             4

# %%
sns.pairplot(df)

# %%
sns.pairplot(df)
plt.show()
